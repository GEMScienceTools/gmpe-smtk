# %%
import os
import shutil
from smtk.parsers.esm22_flatfile_parser import ESM22FlatfileParser
import pickle

# %%
#Paths to specify when running the ESM22 parser

DATA = os.path.abspath('')

ESM22_flatfile_directory = os.path.join(DATA,'data','ESM22_Albania_test.csv')

output_path_for_converted_flatfile = os.path.join(DATA,'data','converted_ESM22_Albania_test.csv')

#Output path for created metadata used in SMTK
output_database = os.path.join(DATA,'data','ESM22_conversion_test_metadata')
if os.path.exists(output_database):
   shutil.rmtree(output_database)

#Path to converted flatfile to be parsed (same as output path for converted flatfile)
input_fileset = output_path_for_converted_flatfile

# %%
pd.Read_cs

# %%
#Parse flatfile
parser = ESM22FlatfileParser.autobuild("000", "ESM22 Test", output_database, input_fileset, ESM22_flatfile_directory, output_path_for_converted_flatfile)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Parse flatfile
# ----> 2 parser = ESM22FlatfileParser.autobuild("000", "ESM22 Test", output_database, input_fileset, ESM22_flatfile_directory, output_path_for_converted_flatfile)
#
# File ~\openquake\lib\site-packages\smtk\parsers\esm22_flatfile_parser.py:155, in ESM22FlatfileParser.autobuild(cls, dbid, dbname, output_location, flatfile_location, ESM22_flatfile_directory, output_path_for_converted_flatfile)
#     152 ESM22 = pd.read_csv(ESM22_flatfile_directory) #Need to specify ESM22_flatfile_directory and filename
#     154 # Create default values for headers not considered in ESM22 flatfile format
# --> 155 default_string = pd.Series(np.full(np.size(ESM22.event_id),str("")))
#     157 # Assign strike-slip to unknown faulting mechanism
#     158 r_fm_type = ESM22.fm_type_code.fillna('SS')
#
# ...

# %%
with open(os.path.join(output_database, "metadatafile.pkl"), "rb") as f:
            db = pickle.load(f)

# %%
db.records
# Out:
# ...
#  ...]

# %%
len(db)
# Out:
# 1383
