# %%
"""
Following preparation of a flatfile often have to reconvert to yyyy-mm-dd hh:mm:ss
datetime format. This code resaves with correct delimiter for parsing
"""
import os
import pandas as pd
DATA = os.path.abspath('')
ESM_flatfile_directory = os.path.join(DATA,'data','ESM22_Albania_filtered_test.csv')
ESM=pd.read_csv(ESM_flatfile_directory)

# %%
output_base_directory = os.path.abspath('')
output_directory = os.path.join(output_base_directory,'..','..','data','sm','converted')
filename_output = '\\Final_Albania_dataset.csv'
output_path=str(output_directory)+filename_output
ESM.to_csv(output_path,sep=';')

# %%
ESM
# Out:
#     Unnamed: 0               event_id           event_time ev_nation_code  \
# 0            0  EMSC-20161029_0000147  2016-10-29T20:15:28             AL
# 1            1  EMSC-20160831_0000112  2016-08-31T22:20:53             AL
# 2            2  EMSC-20191128_0000157  2019-11-28T23:00:44             AL
# 3            3  EMSC-20150207_0000001  2015-02-07T01:56:23             AL
# 4            4  EMSC-20170127_0000087  2017-01-27T17:07:59             AL
# 5            5  EMSC-20191128_0000068  2019-11-28T10:52:41             AL
# 6            6  EMSC-20151101_0000023  2015-11-01T06:26:19             AL
# 7            7  EMSC-20190921_0000063  2019-09-21T14:04:25             AL
# 8            8  EMSC-20151031_0000024  2015-10-31T09:20:34             AL
# 9            9  EMSC-20161104_0000026  2016-11-04T05:08:54             AL
# 10          26  EMSC-20170918_0000091  2017-09-18T16:47:11             AL
# 11          27  EMSC-20161029_0000147  2016-10-29T20:15:28             AL
# ...
